# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
cardio = pd.read_csv('/content/Cardiotocographic.csv')

# %%
cardio
# Out:
#               LB        AC        FM        UC        DL            DS  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.000000e+00
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.000000e+00
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.000000e+00
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.000000e+00
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.000000e+00
# 5     134.000000  0.001116  0.000000  0.010493  0.009444  0.000000e+00
# 6     134.000000  0.001403  0.000000  0.012623  0.008415  0.000000e+00
# 7     122.000000  0.000000  0.000000  0.000000  0.000000  0.000000e+00
# 8     122.000000  0.038567  0.000000  0.001517  0.000000  0.000000e+00
# 9     122.000000  0.000000  0.000000  0.002967  0.000000  0.000000e+00
# 10    151.000000  0.000000  0.000000  0.000834  0.000834  0.000000e+00
# 11    150.000000  0.000000  0.000000  0.001014  0.000983  0.000000e+00
# ...

# %%
cardio.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
cardio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
cardio.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
type(cardio)
cardio.shape
# Out:
# (2126, 14)

# %%
cardio1 = cardio.copy()
cardio1
# Out:
#               LB        AC        FM        UC        DL            DS  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.000000e+00
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.000000e+00
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.000000e+00
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.000000e+00
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.000000e+00
# 5     134.000000  0.001116  0.000000  0.010493  0.009444  0.000000e+00
# 6     134.000000  0.001403  0.000000  0.012623  0.008415  0.000000e+00
# 7     122.000000  0.000000  0.000000  0.000000  0.000000  0.000000e+00
# 8     122.000000  0.038567  0.000000  0.001517  0.000000  0.000000e+00
# 9     122.000000  0.000000  0.000000  0.002967  0.000000  0.000000e+00
# 10    151.000000  0.000000  0.000000  0.000834  0.000834  0.000000e+00
# 11    150.000000  0.000000  0.000000  0.001014  0.000983  0.000000e+00
# ...

# %%
pd.set_option('display.min_rows',None)

# %%
cardio1
# Out:
#               LB        AC        FM        UC        DL            DS  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.000000e+00
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.000000e+00
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.000000e+00
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.000000e+00
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.000000e+00
# 5     134.000000  0.001116  0.000000  0.010493  0.009444  0.000000e+00
# 6     134.000000  0.001403  0.000000  0.012623  0.008415  0.000000e+00
# 7     122.000000  0.000000  0.000000  0.000000  0.000000  0.000000e+00
# 8     122.000000  0.038567  0.000000  0.001517  0.000000  0.000000e+00
# 9     122.000000  0.000000  0.000000  0.002967  0.000000  0.000000e+00
# 10    151.000000  0.000000  0.000000  0.000834  0.000834  0.000000e+00
# 11    150.000000  0.000000  0.000000  0.001014  0.000983  0.000000e+00
# ...

# %%
cardio1.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
cardio1.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
[features for features in cardio1.columns if cardio1[features].isnull().sum()>0]
# Out:
# ['LB', 'AC', 'DS', 'DP', 'MLTV', 'Width', 'Tendency', 'NSP']

# %%
sns.heatmap(cardio1.isnull(),yticklabels=False,xticklabels=True,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
cardio1['LB'].fillna(cardio1['LB'].mean(),inplace=True)
cardio1['AC'].fillna(cardio1['AC'].mean(),inplace=True)
cardio1['DS'].fillna(cardio1['DS'].mean(),inplace=True)
cardio1['DP'].fillna(cardio1['DP'].mean(),inplace=True)
cardio1['MLTV'].fillna(cardio1['MLTV'].mean(),inplace=True)
cardio1['Width'].fillna(cardio1['Width'].mean(),inplace=True)
cardio1['Tendency'].fillna(cardio1['Tendency'].mean(),inplace=True)
cardio1['NSP'].fillna(cardio1['NSP'].mean(),inplace=True)

# %%
cardio1
# Out:
#               LB        AC        FM        UC        DL            DS  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.000000e+00
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.000000e+00
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.000000e+00
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.000000e+00
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.000000e+00
# 5     134.000000  0.001116  0.000000  0.010493  0.009444  0.000000e+00
# 6     134.000000  0.001403  0.000000  0.012623  0.008415  0.000000e+00
# 7     122.000000  0.000000  0.000000  0.000000  0.000000  0.000000e+00
# 8     122.000000  0.038567  0.000000  0.001517  0.000000  0.000000e+00
# 9     122.000000  0.000000  0.000000  0.002967  0.000000  0.000000e+00
# 10    151.000000  0.000000  0.000000  0.000834  0.000834  0.000000e+00
# 11    150.000000  0.000000  0.000000  0.001014  0.000983  0.000000e+00
# ...

# %%
cardio1.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %% [markdown]
# Untill here calculated all the null and filled the null values.

# %%
cardio1[cardio1.duplicated()].shape
# Out:
# (2, 14)

# %%
cardio1[cardio1.duplicated()]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1115   39.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %% [markdown]
# Dropping duplicate values

# %%
cardio_cleaned = cardio1.drop_duplicates()

# %%
cardio_cleaned.shape
# Out:
# (2124, 14)

# %%
cardio_cleaned
# Out:
#               LB        AC        FM        UC        DL            DS  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.000000e+00
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.000000e+00
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.000000e+00
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.000000e+00
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.000000e+00
# 5     134.000000  0.001116  0.000000  0.010493  0.009444  0.000000e+00
# 6     134.000000  0.001403  0.000000  0.012623  0.008415  0.000000e+00
# 7     122.000000  0.000000  0.000000  0.000000  0.000000  0.000000e+00
# 8     122.000000  0.038567  0.000000  0.001517  0.000000  0.000000e+00
# 9     122.000000  0.000000  0.000000  0.002967  0.000000  0.000000e+00
# 10    151.000000  0.000000  0.000000  0.000834  0.000834  0.000000e+00
# 11    150.000000  0.000000  0.000000  0.001014  0.000983  0.000000e+00
# ...

# %%
import seaborn as sns
sns.pairplot(cardio_cleaned.iloc[:,:])

# %%
cardio_cleaned.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'LB'}>, <Axes: title={'center': 'AC'}>,
#         <Axes: title={'center': 'FM'}>, <Axes: title={'center': 'UC'}>],
#        [<Axes: title={'center': 'DL'}>, <Axes: title={'center': 'DS'}>,
#         <Axes: title={'center': 'DP'}>, <Axes: title={'center': 'ASTV'}>],
#        [<Axes: title={'center': 'MSTV'}>,
#         <Axes: title={'center': 'ALTV'}>,
#         <Axes: title={'center': 'MLTV'}>,
#         <Axes: title={'center': 'Width'}>],
#        [<Axes: title={'center': 'Tendency'}>,
#         <Axes: title={'center': 'NSP'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
cardio1['DS'].sum()
# Out:
# 0.005334098933140062

# %%
cardio_cleaned.boxplot(column=['LB'])
# Out:
# <Axes: >

# %%
import seaborn as sns
cols = cardio_cleaned.columns
colours = ['#000099', '#ffff00']
sns.heatmap(cardio_cleaned[cols].isnull(),
            cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
cardio_cleaned = cardio_cleaned.dropna()
cardio_cleaned.shape
# Out:
# (2124, 14)

# %% [markdown]
# Normalization of the data

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler
array = cardio_cleaned.values
scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array[:,0:13])
set_printoptions(precision=3)
print(rescaledX[0:5,:])
# Out:
# [[0.42  0.333 0.333 0.332 0.333 0.333 0.333 0.604 0.348 0.491 0.349 0.448
#   0.667]
#  [0.494 0.444 0.333 0.474 0.403 0.333 0.333 0.356 0.426 0.333 0.402 0.573
#   0.5  ]
#  [0.5   0.391 0.333 0.517 0.405 0.333 0.333 0.351 0.426 0.333 0.421 0.573
#   0.5  ]
#  [0.507 0.378 0.333 0.505 0.389 0.333 0.333 0.351 0.441 0.333 0.485 0.548
#   0.667]
#  [0.494 0.446 0.333 0.513 0.333 0.333 0.333 0.351 0.441 0.333 0.464 0.548
#   0.667]]

# %%
from sklearn.preprocessing import StandardScaler
array = cardio_cleaned.values
scaler = StandardScaler().fit(array)
rescaledX = scaler.transform(array)
set_printoptions(precision=3)
print(rescaledX[0:5,:])
# Out:
# [[-1.19  -0.737 -0.147 -1.316 -0.567 -0.018 -0.21   1.382 -0.736  1.542
#   -0.76  -0.151  1.063  1.084]
#  [-0.12   0.723 -0.147  0.595  0.387 -0.018 -0.21  -1.596  0.627 -0.485
#    0.274  1.394 -0.493 -0.475]
#  [-0.031  0.023 -0.147  1.171  0.426 -0.018 -0.21  -1.649  0.627 -0.485
#    0.662  1.394 -0.493 -0.475]
#  [ 0.059 -0.151 -0.147  1.003  0.199 -0.018 -0.21  -1.649  0.882 -0.485
#    1.903  1.089  1.064 -0.475]
#  [-0.124  0.754 -0.147  1.123 -0.567 -0.018 -0.21  -1.649  0.882 -0.485
#    1.502  1.089  1.064 -0.475]]

# %% [markdown]
#  **No questions asked **
