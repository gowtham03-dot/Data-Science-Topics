# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
sd=pd.read_csv('sales_data_with_discounts.csv')

# %%
sd
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
sd.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
numerics=sd.select_dtypes(include=['int','float']).columns

# %%
numerics
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
sd.isnull()
# Out:
#       Date    Day    SKU   City  Volume     BU  Brand  Model  Avg Price  \
# 0    False  False  False  False   False  False  False  False      False
# 1    False  False  False  False   False  False  False  False      False
# 2    False  False  False  False   False  False  False  False      False
# 3    False  False  False  False   False  False  False  False      False
# 4    False  False  False  False   False  False  False  False      False
# ..     ...    ...    ...    ...     ...    ...    ...    ...        ...
# 445  False  False  False  False   False  False  False  False      False
# 446  False  False  False  False   False  False  False  False      False
# 447  False  False  False  False   False  False  False  False      False
# 448  False  False  False  False   False  False  False  False      False
# 449  False  False  False  False   False  False  False  False      False
#
#      Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value
# ...

# %%
sd[numerics].mean()
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %%
for column in numerics:print(sd[column].mean())
# Out:
# 5.066666666666666
# 10453.433333333332
# 33812.83555555555
# 15.155241895330914
# 3346.499424342415
# 30466.336131270138

# %%
sd[numerics].mode()
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0       3.0      400.0            24300.0           5.007822        69.177942
# 1       NaN      450.0                NaN           5.055218        73.025199
# 2       NaN      500.0                NaN           5.059801        93.649161
# 3       NaN     1300.0                NaN           5.072124        94.682735
# 4       NaN     8100.0                NaN           5.084108       102.705757
# ..      ...        ...                ...                ...              ...
# 445     NaN        NaN                NaN          19.940610     17900.983733
# 446     NaN        NaN                NaN          19.965340     21153.498820
# 447     NaN        NaN                NaN          19.976879     21496.675367
# 448     NaN        NaN                NaN          19.982257     25328.224204
# 449     NaN        NaN                NaN          19.992407     25738.022194
#
#      Net Sales Value
# ...

# %%
sd[numerics].var()
# Out:
# Volume               1.790646e+01
# Avg Price            3.268830e+08
# Total Sales Value    2.553794e+09
# Discount Rate (%)    1.781348e+01
# Discount Amount      2.033922e+07
# Net Sales Value      2.149125e+09
# dtype: float64

# %%
sd[numerics].std()
# Out:
# Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# Discount Rate (%)        4.220602
# Discount Amount       4509.902963
# Net Sales Value      46358.656624
# dtype: float64

# %%
sd[numerics].median()
# Out:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %%
'''plt.figure(figsize=(10,6))
sd[numerics].hist()
plt.title(f'Histogram of {column}')
plt.xlabel(column)
plt.ylabel('frquency')
plt.grid(True)
plt.show()'''
for column in numerics:
  plt.figure(figsize=(8,8))
  plt.hist(sd[column],bins=20,color='skyblue',edgecolor='black')
  plt.title(f'Histogram of {column}')
  plt.xlabel(column)
  plt.ylabel('frquency')
  plt.grid(True)
  plt.show()

# %%
plt.figure(figsize=(10, 6))
sd[numerics].boxplot()
plt.title('Boxplot of Numerical Variables')
plt.ylabel('Values')
plt.xticks(rotation=45)

plt.show()

# %%
sd.BU.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='BU'>

# %%
sd.Brand.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Brand'>

# %%
sd.Model.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Model'>

# %%
categorial_columns = sd.select_dtypes(include=['object']).columns

# %%
categorial_columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')

# %%
categorial_columns
# Out:
# Index(['City', 'BU', 'Brand', 'Model'], dtype='object')

# %%
sd.City.value_counts()
# Out:
# City
# C    450
# Name: count, dtype: int64

# %%
df = sd.copy()

# %%
df = df.drop(columns=['Day','Date','SKU'],axis=1)

# %%
df_with_dummies = pd.get_dummies(df, columns=['BU','Brand','Model','City'])

# %%
df_with_dummies
# Out:
#        Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0    2.350029   0.091173           2.925721          -0.830289
# 1    1.167129  -0.019570           1.330995          -0.852661
# 2    0.457388   0.312659           1.562775          -1.351631
# 3    0.220808   0.534146           1.719276          -1.949723
# 4   -0.488932  -0.130313          -0.188452           0.673739
# ..        ...        ...                ...                ...
# 445 -0.725512  -0.506840          -0.618334           0.076009
# 446  0.220808  -0.434857          -0.360801           0.451097
# 447 -0.725512  -0.490229          -0.606448           0.903793
# 448 -0.488932  -0.473617          -0.556923           0.388474
# 449 -0.962092  -0.407171          -0.608429           0.042235
#
#      Discount Amount  Net Sales Value  BU_FMCG  BU_Lifestyle  BU_Mobiles  \
# 0           3.952816         2.804756    False         False        True
# ...

# %%
df_with_dummies.head()
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0  2.350029   0.091173           2.925721          -0.830289         3.952816
# 1  1.167129  -0.019570           1.330995          -0.852661         1.849014
# 2  0.457388   0.312659           1.562775          -1.351631         1.622995
# 3  0.220808   0.534146           1.719276          -1.949723         1.113807
# 4 -0.488932  -0.130313          -0.188452           0.673739         0.227852
#
#    Net Sales Value  BU_FMCG  BU_Lifestyle  BU_Mobiles  Brand_Babaji  ...  \
# 0         2.804756    False         False        True         False  ...
# 1         1.271026    False         False        True         False  ...
# 2         1.545675    False         False        True         False  ...
# 3         1.765810    False         False        True         False  ...
# 4        -0.227595    False         False        True         False  ...
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
df[numerics] = std.fit_transform(df[numerics])

# %%
df[numerics]
# Out:
#        Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0    2.350029   0.091173           2.925721          -0.830289
# 1    1.167129  -0.019570           1.330995          -0.852661
# 2    0.457388   0.312659           1.562775          -1.351631
# 3    0.220808   0.534146           1.719276          -1.949723
# 4   -0.488932  -0.130313          -0.188452           0.673739
# ..        ...        ...                ...                ...
# 445 -0.725512  -0.506840          -0.618334           0.076009
# 446  0.220808  -0.434857          -0.360801           0.451097
# 447 -0.725512  -0.490229          -0.606448           0.903793
# 448 -0.488932  -0.473617          -0.556923           0.388474
# 449 -0.962092  -0.407171          -0.608429           0.042235
#
#      Discount Amount  Net Sales Value
# 0           3.952816         2.804756
# 1           1.849014         1.271026
# 2           1.622995         1.545675
# 3           1.113807         1.765810
# ...

# %% [markdown]
# **Standardization:** We can use standardization to achieve normally distributed data with mean-0 and SD-1 and prevents in features having larger scales.
#
#
# **One-Hot Encoding:**One-Hot encoding helps conversion of categorical columns into numerical columns by creating them into binary(0 and 1).
