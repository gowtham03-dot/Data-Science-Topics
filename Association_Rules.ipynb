# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder
# !pip install mlxtend

# %%
Ship = pd.read_csv('/content/Titanic.csv')
Ship
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      Class  Gender    Age Survived
# 0      3rd    Male  Child       No
# 1      3rd    Male  Child       No
# 2      3rd    Male  Child       No
# 3      3rd    Male  Child       No
# 4      3rd    Male  Child       No
# ...    ...     ...    ...      ...
# 2196  Crew  Female  Adult      Yes
# 2197  Crew  Female  Adult      Yes
# 2198  Crew  Female  Adult      Yes
# 2199  Crew  Female  Adult      Yes
# 2200  Crew  Female  Adult      Yes
#
# [2201 rows x 4 columns]

# %%
Ship1 = Ship.copy()
Ship1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      Class  Gender    Age Survived
# 0      3rd    Male  Child       No
# 1      3rd    Male  Child       No
# 2      3rd    Male  Child       No
# 3      3rd    Male  Child       No
# 4      3rd    Male  Child       No
# ...    ...     ...    ...      ...
# 2196  Crew  Female  Adult      Yes
# 2197  Crew  Female  Adult      Yes
# 2198  Crew  Female  Adult      Yes
# 2199  Crew  Female  Adult      Yes
# 2200  Crew  Female  Adult      Yes
#
# [2201 rows x 4 columns]

# %%
Ship1.describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        Class Gender    Age Survived
# count   2201   2201   2201     2201
# unique     4      2      2        2
# top     Crew   Male  Adult       No
# freq     885   1731   2092     1490

# %%
Ship1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2201 entries, 0 to 2200
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Class     2201 non-null   object
#  1   Gender    2201 non-null   object
#  2   Age       2201 non-null   object
#  3   Survived  2201 non-null   object
# dtypes: object(4)
# memory usage: 68.9+ KB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
Ship1.isnull().sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Class       0
# Gender      0
# Age         0
# Survived    0
# dtype: int64

# %%
Ship1.duplicated()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2196     True
# 2197     True
# 2198     True
# 2199     True
# 2200     True
# Length: 2201, dtype: bool

# %%
Ship1.duplicated().sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2177

# %%
Ship1.drop_duplicates(inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
Ship1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      Class  Gender    Age Survived
# 0      3rd    Male  Child       No
# 35     3rd  Female  Child       No
# 52     1st    Male  Adult       No
# 170    2nd    Male  Adult       No
# 324    3rd    Male  Adult       No
# 711   Crew    Male  Adult       No
# 1381   1st  Female  Adult       No
# 1385   2nd  Female  Adult       No
# 1398   3rd  Female  Adult       No
# 1487  Crew  Female  Adult       No
# 1490   1st    Male  Child      Yes
# 1495   2nd    Male  Child      Yes
# 1506   3rd    Male  Child      Yes
# 1519   1st  Female  Child      Yes
# 1520   2nd  Female  Child      Yes
# 1533   3rd  Female  Child      Yes
# ...

# %%
df=pd.get_dummies(Ship1)
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      Class_1st  Class_2nd  Class_3rd  Class_Crew  Gender_Female  Gender_Male  \
# 0        False      False       True       False          False         True
# 35       False      False       True       False           True        False
# 52        True      False      False       False          False         True
# 170      False       True      False       False          False         True
# 324      False      False       True       False          False         True
#
#      Age_Adult  Age_Child  Survived_No  Survived_Yes
# 0        False       True         True         False
# ...

# %%
#apriori algorithm
frequent_itemsets = apriori(df, min_support=0.1, use_colnames=True)
frequent_itemsets
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      support                                  itemsets
# 0   0.250000                               (Class_1st)
# 1   0.250000                               (Class_2nd)
# 2   0.333333                               (Class_3rd)
# 3   0.166667                              (Class_Crew)
# 4   0.500000                           (Gender_Female)
# 5   0.500000                             (Gender_Male)
# 6   0.666667                               (Age_Adult)
# 7   0.333333                               (Age_Child)
# 8   0.416667                             (Survived_No)
# 9   0.583333                            (Survived_Yes)
# ...

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.7)
rules
rules.sort_values('lift',ascending = False).head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                       antecedents                 consequents  \
# 22                    (Age_Child)                 (Class_3rd)
# 29                   (Class_Crew)                 (Age_Adult)
# 28                    (Age_Adult)                (Class_Crew)
# 23                    (Class_3rd)                 (Age_Child)
# 69                 (Survived_Yes)  (Gender_Female, Age_Child)
# 51                 (Survived_Yes)                 (Age_Child)
# ...

# %%
rules.sort_values('lift',ascending = False)[0:20]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                       antecedents                    consequents  \
# 22                    (Age_Child)                    (Class_3rd)
# 29                   (Class_Crew)                    (Age_Adult)
# 28                    (Age_Adult)                   (Class_Crew)
# 23                    (Class_3rd)                    (Age_Child)
# 69                 (Survived_Yes)     (Gender_Female, Age_Child)
# ...

# %%
rules[rules.lift>1]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                       antecedents                    consequents  \
# 6                     (Class_1st)                 (Survived_Yes)
# 7                  (Survived_Yes)                    (Class_1st)
# 14                    (Class_2nd)                 (Survived_Yes)
# 15                 (Survived_Yes)                    (Class_2nd)
# 22                    (Age_Child)                    (Class_3rd)
# ...

# %% [markdown]
# **Q1)** Lift : It is a measure of how much more the likely the two items are to be bought together and is calculated as the ratio of the observed support of the two items together if they were independent and it is important in the association rules because it helps us to identify rules that are truly interesting and not just due to chance.
#
#
# **Q2)**Support: is an indication of how frequently an itemset appears in the dataset. It is the proportion of transactions that contain the itemset.
# Support(X) = (Transactions containing X) / (Total Transactions)
# Support(X->Y) = (Transactions containing X and Y) / (Total Transactions)
# Confidence: indicates how likely item Y is purchased when item X is purchased, expressed as {X -> Y}. This is measured by the proportion of transactions with item X, in which item Y also appears.
# Confidence(X->Y) = Support(X->Y) / Support(X)
#
# **Q3)**Limitations in association rules mining:
# Computational Complexity;
# Spurious Associations;
# Rare item Problem ;
# Minimum Support and Confidence Thresholds;
# Handling Categorical Data ;
# Overfitting ;
# Actionability.
